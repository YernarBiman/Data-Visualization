# %%
from sklearn import datasets
import json
import umap
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
x, y = iris["data"], iris["target"]

# %%
reducer = umap.UMAP()

# %%
embedding = reducer.fit_transform(x)
embedding.shape
# Out:
# (150, 2)

# %%
data = pd.DataFrame(embedding, columns=["Comp1","Comp2"])
data["Label"] = y

# %%
data
# Out:
#          Comp1     Comp2  Label
# 0    20.515282  8.747917      0
# 1    18.168036  8.442636      0
# 2    18.651525  9.002230      0
# 3    18.355806  8.862788      0
# 4    20.106205  8.723332      0
# ..         ...       ...    ...
# 145  -6.959932  5.126141      2
# 146  -3.915747  5.209775      2
# 147  -6.350310  5.158710      2
# 148  -6.972059  5.557413      2
# 149  -3.209392  4.825198      2
#
# [150 rows x 3 columns]

# %%
# TODO add the Target Information into  your json file
with open('data_umap.json', 'w') as f:
    json.dump(np.array(data).tolist(), f)

# %%
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

sns.lmplot(x='Comp1',
           y='Comp2',
           data=data,
           fit_reg=False,
           legend=True,
           size=9,
           hue='Label',
           scatter_kws={"s":200, "alpha":0.3}
          )

plt.title("UMAP", weight='bold').set_fontsize('14')
plt.xlabel('Comp 1')
plt.ylabel('Comp 2')
# Out:
# C:\Users\Yernar-PC\anaconda3\envs\tf\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(29.866674166666684, 0.5, 'Comp 2')
